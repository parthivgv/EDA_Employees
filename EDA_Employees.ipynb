# %% [markdown]
# <a href="https://colab.research.google.com/github/parthivgv/EDA_Employees/blob/main/EDA_Employees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the libraries

# %%
import pandas as pd
import numpy as np

# read dataset using pandas
df = pd.read_csv('/content/employees.csv')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
df.head()
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.tail()
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'],format = 'mixed')

# %%
df['Start Date']
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
df['First Name']= df['First Name'].astype('string')

# %%
help(pd.Series.astype)
# Out:
# Help on function astype in module pandas.core.generic:
#
# astype(self: 'NDFrameT', dtype, copy: 'bool_t | None' = None, errors: 'IgnoreRaise' = 'raise') -> 'NDFrameT'
#     Cast a pandas object to a specified dtype ``dtype``.
#
#     Parameters
#     ----------
#     dtype : str, data type, Series or Mapping of column name -> data type
#         Use a str, numpy.dtype, pandas.ExtensionDtype or Python type to
#         cast entire pandas object to the same type. Alternatively, use a
#         mapping, e.g. {col: dtype, ...}, where col is a column label and dtype is
#         a numpy.dtype or Python type to cast one or more of the DataFrame's
#         columns to column-specific types.
#     copy : bool, default True
#         Return a copy when ``copy=True`` (be very careful setting
#         ``copy=False`` as changes to values then may propagate to other
#         pandas objects).
#     errors : {'raise', 'ignore'}, default 'raise'
#         Control raising of exceptions on invalid data for provided dtype.
#
#         - ``raise`` : allow exceptions to be raised
#         - ``ignore`` : suppress exceptions. On error return original object.
#
#     Returns
#     -------
#     same type as caller
#
#     See Also
#     --------
#     to_datetime : Convert argument to datetime.
#     to_timedelta : Convert argument to timedelta.
#     to_numeric : Convert argument to a numeric type.
#     numpy.ndarray.astype : Cast a numpy array to a specified type.
#
#     Notes
#     -----
#     .. versionchanged:: 2.0.0
#
#         Using ``astype`` to convert from timezone-naive dtype to
#         timezone-aware dtype will raise an exception.
#         Use :meth:`Series.dt.tz_localize` instead.
#
#     Examples
#     --------
#     Create a DataFrame:
#
#     >>> d = {'col1': [1, 2], 'col2': [3, 4]}
#     >>> df = pd.DataFrame(data=d)
#     >>> df.dtypes
#     col1    int64
#     col2    int64
#     dtype: object
#
#     Cast all columns to int32:
#
#     >>> df.astype('int32').dtypes
#     col1    int32
#     col2    int32
#     dtype: object
#
#     Cast col1 to int32 using a dictionary:
#
#     >>> df.astype({'col1': 'int32'}).dtypes
#     col1    int32
#     col2    int64
#     dtype: object
#
#     Create a series:
#
#     >>> ser = pd.Series([1, 2], dtype='int32')
#     >>> ser
#     0    1
#     1    2
#     dtype: int32
#     >>> ser.astype('int64')
#     0    1
#     1    2
#     dtype: int64
#
#     Convert to categorical type:
#
#     >>> ser.astype('category')
#     0    1
#     1    2
#     dtype: category
#     Categories (2, int32): [1, 2]
#
#     Convert to ordered categorical type with custom ordering:
#
#     >>> from pandas.api.types import CategoricalDtype
#     >>> cat_dtype = CategoricalDtype(
#     ...     categories=[2, 1], ordered=True)
#     >>> ser.astype(cat_dtype)
#     0    1
#     1    2
#     dtype: category
#     Categories (2, int64): [2 < 1]
#
#     Create a series of dates:
#
#     >>> ser_date = pd.Series(pd.date_range('20200101', periods=3))
#     >>> ser_date
#     0   2020-01-01
#     1   2020-01-02
#     2   2020-01-03
#     dtype: datetime64[ns]

# %%
df['Gender']= df['Gender'].astype('string')

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df['Team']= df['Team'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    string
#  1   Gender             855 non-null    string
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    string
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(1), string(3)
# memory usage: 55.8+ KB

# %%
df['Gender'].dtype
# Out:
# string[python]

# %%
columns = {'First Name':'First_Name',
           'Start date': 'Start_Date',
           'Last Login Time': 'Last_Login_Time',
           'Bonus %':'Bonus_perct',
           'Senior Management': 'Senior_Management'}

df.rename(columns=columns, inplace=True)

# %%
df.columns
# Out:
# Index(['First_Name', 'Gender', 'Start Date', 'Last_Login_Time', 'Salary',
#        'Bonus_perct', 'Senior_Management', 'Team'],
#       dtype='object')

# %%
df.head(4)
# Out:
#   First_Name  Gender Start Date Last_Login_Time  Salary  Bonus_perct  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308        6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933        4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590       11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705        9.340
#
#    Senior_Management       Team
# 0               True  Marketing
# 1               True       <NA>
# 2              False    Finance
# 3               True    Finance

# %%
df.nunique()
# Out:
# First_Name           200
# Gender                 2
# Start Date           972
# Last_Login_Time      720
# Salary               995
# Bonus_perct          971
# Senior_Management      2
# Team                  10
# dtype: int64

# %%
df.count()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management    1000
# Team                  957
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
df['Senior Management'].value_counts()
# Out:
# Senior Management
# True     535
# False    465
# Name: count, dtype: int64

# %%
df['Senior Management'].isnull().sum()
# Out:
# 0

# %%
df['Team'].value_counts()
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %% [markdown]
# # Handling missing values

# %%
isnull() #checking for missing values
notnull() #checking for values
dropna() #deleting a missing values
fillna() #filling a missing value
bfill()  #backwardfill
ffill()  #forwardfill
replace()
interpolate() #predicting the value for missing value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-61a0112cfabd> in <cell line: 1>()
# ----> 1 isnull() #checking for missing values
#       2 notnull() #checking for values
#       3 dropna() #deleting a missing values
#       4 fillna() #filling a missing value
#       5 bfill()  #backwardfill
#
# NameError: name 'isnull' is not defined

# %%
df.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# 3                False  False
# 4                False  False
# ..                 ...    ...
# 995              False  False
# 996              False  False
# 997              False  False
# 998              False  False
# 999              False  False
#
# [1000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management      0
# Team                  43
# dtype: int64

# %%
df.isna().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management      0
# Team                  43
# dtype: int64

# %%
df['Gender'].fillna("No Gender", inplace = True)

# %%
df.isna().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management     0
# Team                 43
# dtype: int64

# %%
df['Gender']
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    No Gender
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object

# %%
df['Senior Management'].value_counts()
# Out:
# Senior Management
# True     535
# False    465
# Name: count, dtype: int64

# %%
df['Senior Management'].mode()
# Out:
# 0    True
# Name: Senior Management, dtype: bool

# %%
mode = df['Senior Management'].mode()[0]
df['Senior Management'] = df['Senior Management'].replace(np.nan, mode)

# %%
df['Senior Management'].head(40)
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22     True
# 23     True
# 24    False
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# Name: Senior Management, dtype: bool

# %%
df.isnull().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management     0
# Team                 43
# dtype: int64

# %%
df = df.dropna(axis = 0,how = 'any')  #axis = 0 --> row

# %%
df.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         899 non-null    object
#  1   Gender             899 non-null    object
#  2   Start Date         899 non-null    object
#  3   Last Login Time    899 non-null    object
#  4   Salary             899 non-null    int64
#  5   Bonus %            899 non-null    float64
#  6   Senior Management  899 non-null    bool
#  7   Team               899 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 57.1+ KB

# %%
df
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male  08-06-1993        12:42 PM   97308    6.945
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis       Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [899 rows x 8 columns]

# %%
df['Final_salary']=round(df['Salary'] + ((df['Salary'] * df['Bonus_perct'])/100),2)

# %%
df['Final_salary']
# Out:
# 0      104066.04
# 2      146075.36
# 3      151660.05
# 4      102406.95
# 5      126823.25
#          ...
# 995    154548.04
# 996     50732.63
# 997     98291.15
# 998     67750.92
# 999    143163.51
# Name: Final_salary, Length: 899, dtype: float64

# %%
df
# Out:
#     First_Name     Gender  Start Date Last_Login_Time  Salary  Bonus_perct  \
# 0      Douglas       Male  08-06-1993        12:42 PM   97308        6.945
# 2        Maria     Female   4/23/1993        11:17 AM  130590       11.858
# 3        Jerry       Male  03-04-2005         1:00 PM  138705        9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004        1.389
# 5       Dennis       Male   4/18/1987         1:35 AM  115163       10.125
# ..         ...        ...         ...             ...     ...          ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483       16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392       19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914        1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500       11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949       10.169
#
#      Senior_Management                  Team  Final_salary
# 0                 True             Marketing     104066.04
# 2                False               Finance     146075.36
# 3                 True               Finance     151660.05
# 4                 True       Client Services     102406.95
# 5                False                 Legal     126823.25
# ..                 ...                   ...           ...
# 995              False          Distribution     154548.04
# 996              False               Finance      50732.63
# 997              False               Product      98291.15
# 998              False  Business Development      67750.92
# 999               True                 Sales     143163.51
#
# [899 rows x 9 columns]

# %%
df.describe()
# Out:
#               Salary  Bonus_perct   Final_salary
# count     899.000000   899.000000     899.000000
# mean    90479.672970    10.200201   99677.876407
# std     32743.875488     5.551621   36400.444846
# min     35013.000000     1.015000   36858.930000
# 25%     62412.500000     5.267000   68798.985000
# 50%     90730.000000     9.770000   99308.000000
# 75%    118107.500000    14.868500  129095.255000
# max    149908.000000    19.944000  178258.600000

# %% [markdown]
# #Outlier

# %%
Q1_salary = np.quantile(df['Salary'],0.25)
Q2_salary = np.quantile(df['Salary'],0.50)
Q3_salary = np.quantile(df['Salary'],0.75)
print('Q1:' ,Q1_salary, 'Q2:',Q2_salary, 'Q3:',Q3_salary)
# Out:
# Q1: 62412.5 Q2: 90730.0 Q3: 118107.5

# %%
IQR = (Q3_salary - Q1_salary)/2
print('IQR: ',IQR)
# Out:
# IQR:  27847.5

# %%
Upper = Q3_salary+1.5*IQR
Lower = Q1_salary-1.5*IQR
[Lower,Upper]
# Out:
# [20641.25, 159878.75]

# %%
Q1_salary = np.quantile(df['Salary'],0.25)
Q2_salary = np.quantile(df['Salary'],0.50)
Q3_salary = np.quantile(df['Salary'],0.75)
print('min: ',df['Salary'].min(), 'Q1:' ,Q1_salary, 'Q2:',Q2_salary, 'Q3:',Q3_salary,'max:',df['Salary'].max())
# Out:
# min:  35013 Q1: 62412.5 Q2: 90730.0 Q3: 118107.5 max: 149908

# %%
df['Salary'].min(),df['Salary'].max()
# Out:
# (35013, 149908)

# %% [markdown]
# # Data Visualization

# %%
# Data Visualization is the process of analyzing data in the forms of graphs or maps,making it lot easier to understand the trends or patterns in the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x='Salary',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(x='Salary',hue = 'Gender',data=df)
plt.show()

# %%
sns.boxplot(x='Salary',data=df)
plt.show()

# %%
sns.kdeplot(x='Salary',hue = 'Gender', data=df)
plt.show()

# %%
df.describe(include = 'all')
# Out:
#        First_Name  Gender  Start Date Last_Login_Time         Salary  \
# count         899     899         899             899     899.000000
# unique        200       3         879             681            NaN
# top       Marilyn  Female  10/30/2004         1:35 PM            NaN
# freq           11     393           2               5            NaN
# mean          NaN     NaN         NaN             NaN   90479.672970
# std           NaN     NaN         NaN             NaN   32743.875488
# min           NaN     NaN         NaN             NaN   35013.000000
# 25%           NaN     NaN         NaN             NaN   62412.500000
# 50%           NaN     NaN         NaN             NaN   90730.000000
# 75%           NaN     NaN         NaN             NaN  118107.500000
# max           NaN     NaN         NaN             NaN  149908.000000
#
#         Bonus_perct Senior_Management             Team   Final_salary
# count    899.000000               899              899     899.000000
# unique          NaN                 2               10            NaN
# top             NaN              True  Client Services            NaN
# freq            NaN               450              100            NaN
# mean      10.200201               NaN              NaN   99677.876407
# std        5.551621               NaN              NaN   36400.444846
# min        1.015000               NaN              NaN   36858.930000
# 25%        5.267000               NaN              NaN   68798.985000
# 50%        9.770000               NaN              NaN   99308.000000
# 75%       14.868500               NaN              NaN  129095.255000
# max       19.944000               NaN              NaN  178258.600000

# %%
df.describe(include = ['string','bool'])
# Out:
#        Senior_Management
# count                899
# unique                 2
# top                 True
# freq                 450

# %% [markdown]
# #Relationship of variables

# %%
sns.scatterplot(x="Salary",y='Bonus_perct',data=df)
#placing legend ouside the figure
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(x="Salary",y='Bonus_perct',data=df,hue='Gender')
#placing legend ouside the figure
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %%
df['Salary'].corr(df['Bonus_perct'])
# Out:
# -0.01702025486966288

# %%
df['Bonus_perct']
# Out:
# 0       6.945
# 2      11.858
# 3       9.340
# 4       1.389
# 5      10.125
#         ...
# 995    16.655
# 996    19.675
# 997     1.421
# 998    11.985
# 999    10.169
# Name: Bonus_perct, Length: 899, dtype: float64

# %%
df['Bonus_perct'].min()
# Out:
# 1.015

# %%
df[df['Bonus_perct']>=19]
# Out:
#     First_Name  Gender  Start Date Last_Login_Time  Salary  Bonus_perct  \
# 18       Diana  Female  10/23/1981        10:27 AM  132940       19.082
# 34       Jerry    Male  01-10-2004        12:56 PM   95734       19.096
# 62         NaN  Female  06-12-2007         5:25 PM   58112       19.414
# 104       John    Male  12/23/1989         7:01 AM   80740       19.305
# 136      Henry    Male   4/24/1995         4:18 AM   43542       19.687
# 150       Sean    Male  05-04-1996         8:59 PM  135490       19.934
# 163      Terry    Male  09-03-1990         9:15 PM   52226       19.135
# 170      Irene  Female   1/29/1992        11:36 AM  133772       19.020
# 179    Jessica  Female  10/23/1995         5:53 AM   68759       19.343
# 196     Steven    Male  11-10-1985        10:53 AM   62719       19.127
# 211      Linda  Female   6/24/2006        12:04 PM  110967       19.612
# 240    Phyllis     NaN   4/21/1984         7:05 PM   94088       19.107
# 249      Betty  Female  06-12-2002         3:59 AM  104896       19.550
# 277     Brenda     NaN   5/29/1991         6:32 AM   82439       19.062
# 294   Virginia  Female  10/20/1999         6:23 AM   46905       19.154
# 299      Emily  Female   1/13/1988         6:42 AM   36711       19.028
# 335     Robert    Male  11/18/2014         5:00 AM   85799       19.930
# 348     Philip    Male  08-02-1989        11:21 AM  129968       19.897
# 372     Albert    Male  02-01-1997         4:20 PM   67827       19.717
# 387     Robert    Male  10/29/1994         4:26 AM  123294       19.894
# 396       Rose  Female  07-06-2002         3:57 PM   63494       19.385
# 403      Craig    Male  02-08-1984         4:45 AM  113506       19.642
# 299              True       Human Resources      43696.37
# 335             False               Finance     102898.74
# 348             False               Finance     155827.73
# 372              True           Engineering      81200.45
# 387             False       Client Services     147822.11
# 396              True       Human Resources      75802.31
# 403             False             Marketing     135800.85
# 409              True       Human Resources      57115.31
# 420              True               Finance     145000.36
# 430             False          Distribution      94490.27
# 450             False                 Legal      65875.53
# 451              True             Marketing     167288.39
# 488             False                 Legal     162982.31
# 489              True       Client Services      55084.64
# 512             False                   NaN      94419.01
# 513             False                   NaN      76019.86
# 551             False           Engineering     145708.84
# 568             False             Marketing     108215.49
# 619              True           Engineering      70331.10
# 629             False             Marketing      89528.38
# 634             False                   NaN      90180.10
# 639              True       Client Services      55713.81
# 646             False               Finance      94799.88
# 685               NaN               Finance     105163.23
# 728              True       Client Services      98557.21
# 748              True  Business Development     113600.44
# 791             False                 Legal     150709.22
# 797             False           Engineering     173783.70
# 803             False               Product      64245.73
# 809             False               Finance      44008.40
# 813              True             Marketing     148057.16
# 830              True          Distribution      97372.49
# 832             False                 Legal     144163.22
# 841             False  Business Development      57783.51
# 842             False               Product     157818.47
# 859             False  Business Development      49851.44
# 872             False  Business Development      88006.16
# 879             False       Client Services      89843.40
# 918             False       Client Services     102578.85
# 925               NaN                 Sales     114452.50
# 926             False          Distribution     130629.06
# 967             False           Engineering     126364.89
# 981             False                 Legal     177709.31
# 993              True           Engineering      67198.08
# 996             False               Finance      50732.63

# %%
len(df[df['Bonus_perct']>=19])
# Out:
# 54

# %%
bonus19 = df[df['Bonus_perct']>=19].sort_values(['Bonus_perct'])

# %%
bonus19
# Out:
#     First_Name     Gender  Start Date Last_Login_Time  Salary  Bonus_perct  \
# 170      Irene     Female   1/29/1992        11:36 AM  133772       19.020
# 299      Emily     Female   1/13/1988         6:42 AM   36711       19.028
# 993       Tina     Female   5/15/1997         3:53 PM   56450       19.040
# 277     Brenda  No Gender   5/29/1991         6:32 AM   82439       19.062
# 619    Beverly     Female  10/22/1990         2:45 PM   59070       19.064
# 803       Lois     Female   7/28/2012        11:39 AM   53954       19.075
# 18       Diana     Female  10/23/1981        10:27 AM  132940       19.082
# 34       Jerry       Male  01-10-2004        12:56 PM   95734       19.096
# 240    Phyllis  No Gender   4/21/1984         7:05 PM   94088       19.107
# 728    Dorothy     Female  10-08-2008        12:22 AM   82744       19.111
# 551     Philip       Male   7/18/1985         6:36 AM  122319       19.122
# 196     Steven       Male  11-10-1985        10:53 AM   62719       19.127
# 879        Amy     Female   5/20/2009         6:26 AM   75415       19.132
# 163      Terry       Male  09-03-1990         9:15 PM   52226       19.135
# 568      Susan     Female   4/18/1986         9:31 AM   90829       19.142
# 294   Virginia     Female  10/20/1999         6:23 AM   46905       19.154
# 859      Robin     Female  10-01-2012         2:44 AM   41808       19.239
# 842     Sandra     Female  02-07-1998        12:39 PM  132327       19.264
# 409     Jeremy       Male   5/29/1994         6:24 AM   47885       19.276
# 981      James       Male   1/15/1993         5:19 PM  148985       19.280
# 420               True               Finance     145000.36
# 179               True               Finance      82059.05
# 396               True       Human Resources      75802.31
# 639               True       Client Services      55713.81
# 430              False          Distribution      94490.27
# 832              False                 Legal     144163.22
# 918              False       Client Services     102578.85
# 926              False          Distribution     130629.06
# 451               True             Marketing     167288.39
# 841              False  Business Development      57783.51
# 629              False             Marketing      89528.38
# 249               True  Business Development     125403.17
# 967              False           Engineering     126364.89
# 791              False                 Legal     150709.22
# 211               True       Human Resources     132729.85
# 748               True  Business Development     113600.44
# 403              False             Marketing     135800.85
# 996              False               Finance      50732.63
# 136              False                 Legal      52114.11
# 450              False                 Legal      65875.53
# 372               True           Engineering      81200.45
# 489               True       Client Services      55084.64
# 809              False               Finance      44008.40
# 813               True             Marketing     148057.16
# 646              False               Finance      94799.88
# 797              False           Engineering     173783.70
# 387              False       Client Services     147822.11
# 348              False               Finance     155827.73
# 830               True          Distribution      97372.49
# 335              False               Finance     102898.74
# 150              False             Marketing     162498.58
# 488              False                 Legal     162982.31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First_Name         899 non-null    object
#  1   Gender             899 non-null    object
#  2   Start Date         899 non-null    object
#  3   Last_Login_Time    899 non-null    object
#  4   Salary             899 non-null    int64
#  5   Bonus_perct        899 non-null    float64
#  6   Senior_Management  899 non-null    bool
#  7   Team               899 non-null    object
#  8   Final_salary       899 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 96.4+ KB

# %% [markdown]
# #hangling outliers

# %%
#load the dataset
df = sns.load_dataset("iris")
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.pairplot(df)

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['sepal_length'],data=df)
plt.show()

# %%
sns.boxplot(x=df['sepal_width'],data=df)
plt.show()

# %%
sns.boxplot(x=df['petal_length'],data=df)
plt.show()

# %%
sns.boxplot(x=df['petal_width'],data=df)
plt.show()

# %%
# IQR

Q1 = np.percentile(df['sepal_width'],25, method = 'midpoint')
Q3 = np.percentile(df['sepal_width'],75, method = 'midpoint')
IQR = (Q3 - Q1)
print('Old shape: ',df.shape)
Upper = Q3 + 1.5*IQR
Lower = Q1 - 1.5*IQR
(Upper,Lower)
# Out:
# Old shape:  (150, 5)
# (4.05, 2.05)

# %%
df['sepal_width'].min(),df['sepal_width'].max()
# Out:
# (2.0, 4.4)

# %%
# upper bound

max_Upper_value = np.where(df['sepal_width']>= Upper)
print(max_Upper_value)
# Out:
# (array([15, 32, 33]),)

# %%
#lower bound

min_Lower_value = np.where(df['sepal_width']<= Lower)
print(min_Lower_value)
# Out:
# (array([60]),)

# %%
df.drop(min_Lower_value[0],inplace=True)

# %%
df.drop(max_Upper_value[0],inplace=True)

# %%
print('New Shape: ',df.shape)
# Out:
# New Shape:  (146, 5)

# %%
sns.boxplot(x='sepal_width',data = df)
# Out:
# <Axes: xlabel='sepal_width'>
